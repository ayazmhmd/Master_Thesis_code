# %%
# !pip install ultralytics

# %%
ls
# Out:
# '$RECYCLE.BIN'/
#  Ayesha/
#  best_model.pth*
# 'birads_classification1 (another copy).ipynb'*
# 'birads_classification1 (copy).ipynb'*
#  birads_classification1.ipynb*
# 'birads_classification (copy).ipynb'*
#  birads_classification.ipynb*
#  classification_code/
#  classification_results/
#  CNN_GLCM.ipynb*
# 'code copy.ipynb'*
#  code.ipynb*
#  cropped_data3/
#  Cropped_data.ipynb*
#  data_processing.ipynb*
#  glcm-other-ml-features.ipynb*
#  handcrafted_features.ipynb*
#  hard_label_efficientnetb0+glcm.ipynb*
#  hard_label_efficientnetb0.ipynb*
# 'hard_label_efficientnet_b3 (copy).ipynb'*
#  hard_label_efficientnetbo_merged.ipynb*
# 'hard_label_efficientnet (copy).ipynb'*
#  hard_label_efficientnet_inbreast-Copy1.ipynb*
#  hard_label_efficientnet_inbreast.ipynb*
#  hard_label_efficientnet.ipynb*
#  hard_label_efficientnet_mammo_clip.ipynb*
#  image_GLCM_features.csv*
#  inbreast_preprocessing.ipynb*
# 'INbreast Release 1.0'/
#  inteligent_cropped_training.ipynb*
#  KAZ/
# ...

# %%
import os
os.chdir('yolo_data/vindr_dataset1_cropped/malignancy_yolo')

# %%
import yaml

def create_yaml_file(class_names, output_path='data.yaml'):
    config = {
        'train': 'train/images',
        'val': 'val/images',
        'nc': len(class_names),
        'names': class_names
    }
    
    with open(output_path, 'w') as f:
        yaml.dump(config, f, sort_keys=False)
    
    print(f"Created YOLO config file at: {output_path}")

create_yaml_file(
    class_names=['lesion'], 
    output_path='data.yaml'
)
# Out:
# Created YOLO config file at: data.yaml

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
from ultralytics import YOLO

model = YOLO("yolov5n.pt")

train_results = model.train(
    data="data.yaml",  
    epochs=50,  
    imgsz=512, 
        # Optimizer settings (SGD)
    optimizer='AdamW',  # Switch from default Adam to SGD
    momentum=0.937,  # SGD momentum
    weight_decay=0.0005,  # L2 regularization
    
    # Learning rate parameters
    lr0=0.01,  # Initial learning rate
    lrf=0.1,  # Final learning rate (lr0 * lrf)
    device=0,
)
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# New https://pypi.org/project/ultralytics/8.3.166 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.158 🚀 Python-3.12.9 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11009MiB)
# ...
