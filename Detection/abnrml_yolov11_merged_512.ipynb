# %%
# !pip install ultralytics

# %%
import os
os.chdir('/workspace/detection')

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

train_results = model.train(
    # ---------------- Core Training ----------------
    data="/workspace/detection/yolo_finding_aug/merged_view/dataset.yaml",
    epochs=60,
    time=None,
    patience=40,
    batch=8,
    imgsz=640,
    
    # ---------------- Device & Workers ----------------
    device='0',
    workers=8,
    
    # ---------------- Saving & Logging ----------------
    save=True,
    save_period=10,
    cache=False,
    project=None,
    exist_ok=True,
    
    # ---------------- Model & Optimization ----------------
    pretrained=True,
    optimizer="AdamW",
    verbose=True,
    seed=0,
    deterministic=True,
    single_cls=False,
    rect=False,
    cos_lr=True,
    close_mosaic=0,
    resume=False,
    amp=True,
    fraction=1.0,
    profile=False,
    freeze=None,
    multi_scale=False,
    
    # ---------------- Loss & Mask ----------------
    overlap_mask=True,
    mask_ratio=4,
    dropout=0.1,
    
    # ---------------- Validation ----------------
    val=True,
    split="val",
    save_json=True,
    
    # ---------------- Inference Params ----------------
    conf=0.0001,
    iou=0.4,
    max_det=100,
    half=False,
    dnn=False,
    plots=True,
    
    # ---------------- Source/Inference (null in train) ----------------
    source=None,
    vid_stride=1,
    stream_buffer=False,
    visualize=False,
    augment=False,
    agnostic_nms=False,
    classes=None,
    retina_masks=False,
    embed=None,
    show=False,
    save_frames=False,
    save_txt=False,
    save_conf=False,
    save_crop=False,
    show_labels=True,
    show_conf=True,
    show_boxes=True,
    line_width=None,
    
    # ---------------- Export ----------------
    format="torchscript",
    keras=False,
    optimize=False,
    int8=False,
    dynamic=False,
    simplify=True,
    opset=None,
    workspace=None,
    nms=False,
    
    # ---------------- Optimizer Params ----------------
    lr0=0.0001,
    lrf=0.01,
    momentum=0.9,
    weight_decay=0.05,
    warmup_epochs=3.0,
    warmup_momentum=0.8,
    warmup_bias_lr=0.01,
    
    # ---------------- Loss Gains ----------------
    box=7.0,
    cls=0.25,
    dfl=1.5,
    pose=12.0,
    kobj=1.0,
    nbs=64,
    
    # ---------------- Augmentation (EXACT) ----------------
    hsv_h=0.4,
    hsv_s=0.4,
    hsv_v=0.4,
    degrees=20.0,
    translate=0.10,
    scale=0.4,
    shear=0.0,
    perspective=0.0,
    flipud=0.25,
    fliplr=0.5,
    bgr=0.0,
    mosaic=0.2,
    mixup=0.3,
    cutmix=0.2,
    copy_paste=0.2,
    copy_paste_mode="flip",
    auto_augment="None",
    erasing=0.3,
    
    # ---------------- Other ----------------
    name="merged_view_finding/yolo11s_640",
)
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA RTX A5000, 24122MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11m.pt")

train_results = model.train(
    # ---------------- Core Training ----------------
    data="/workspace/detection/yolo_finding_aug/merged_view/dataset.yaml",
    epochs=60,
    time=None,
    patience=40,
    batch=8,
    imgsz=640,
    
    # ---------------- Device & Workers ----------------
    device='0',
    workers=8,
    
    # ---------------- Saving & Logging ----------------
    save=True,
    save_period=10,
    cache=False,
    project=None,
    exist_ok=True,
    
    # ---------------- Model & Optimization ----------------
    pretrained=True,
    optimizer="AdamW",
    verbose=True,
    seed=0,
    deterministic=True,
    single_cls=False,
    rect=False,
    cos_lr=True,
    close_mosaic=0,
    resume=False,
    amp=True,
    fraction=1.0,
    profile=False,
    freeze=None,
    multi_scale=False,
    
    # ---------------- Loss & Mask ----------------
    overlap_mask=True,
    mask_ratio=4,
    dropout=0.1,
    
    # ---------------- Validation ----------------
    val=True,
    split="val",
    save_json=True,
    
    # ---------------- Inference Params ----------------
    conf=0.0001,
    iou=0.4,
    max_det=100,
    half=False,
    dnn=False,
    plots=True,
    
    # ---------------- Source/Inference (null in train) ----------------
    source=None,
    vid_stride=1,
    stream_buffer=False,
    visualize=False,
    augment=False,
    agnostic_nms=False,
    classes=None,
    retina_masks=False,
    embed=None,
    show=False,
    save_frames=False,
    save_txt=False,
    save_conf=False,
    save_crop=False,
    show_labels=True,
    show_conf=True,
    show_boxes=True,
    line_width=None,
    
    # ---------------- Export ----------------
    format="torchscript",
    keras=False,
    optimize=False,
    int8=False,
    dynamic=False,
    simplify=True,
    opset=None,
    workspace=None,
    nms=False,
    
    # ---------------- Optimizer Params ----------------
    lr0=0.0001,
    lrf=0.01,
    momentum=0.9,
    weight_decay=0.05,
    warmup_epochs=3.0,
    warmup_momentum=0.8,
    warmup_bias_lr=0.01,
    
    # ---------------- Loss Gains ----------------
    box=7.0,
    cls=0.25,
    dfl=1.5,
    pose=12.0,
    kobj=1.0,
    nbs=64,
    
    # ---------------- Augmentation (EXACT) ----------------
    hsv_h=0.4,
    hsv_s=0.4,
    hsv_v=0.4,
    degrees=20.0,
    translate=0.10,
    scale=0.4,
    shear=0.0,
    perspective=0.0,
    flipud=0.25,
    fliplr=0.5,
    bgr=0.0,
    mosaic=0.2,
    mixup=0.3,
    cutmix=0.2,
    copy_paste=0.2,
    copy_paste_mode="flip",
    auto_augment="None",
    erasing=0.3,
    
    # ---------------- Other ----------------
    name="merged_view_finding/yolo11m_640",
)
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA RTX A5000, 24122MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11l.pt")

train_results = model.train(
    # ---------------- Core Training ----------------
    data="/workspace/detection/yolo_finding_aug/merged_view/dataset.yaml",
    epochs=60,
    time=None,
    patience=40,
    batch=8,
    imgsz=640,
    
    # ---------------- Device & Workers ----------------
    device='0',
    workers=8,
    
    # ---------------- Saving & Logging ----------------
    save=True,
    save_period=10,
    cache=False,
    project=None,
    exist_ok=True,
    
    # ---------------- Model & Optimization ----------------
    pretrained=True,
    optimizer="AdamW",
    verbose=True,
    seed=0,
    deterministic=True,
    single_cls=False,
    rect=False,
    cos_lr=True,
    close_mosaic=0,
    resume=False,
    amp=True,
    fraction=1.0,
    profile=False,
    freeze=None,
    multi_scale=False,
    
    # ---------------- Loss & Mask ----------------
    overlap_mask=True,
    mask_ratio=4,
    dropout=0.1,
    
    # ---------------- Validation ----------------
    val=True,
    split="val",
    save_json=True,
    
    # ---------------- Inference Params ----------------
    conf=0.0001,
    iou=0.4,
    max_det=100,
    half=False,
    dnn=False,
    plots=True,
    
    # ---------------- Source/Inference (null in train) ----------------
    source=None,
    vid_stride=1,
    stream_buffer=False,
    visualize=False,
    augment=False,
    agnostic_nms=False,
    classes=None,
    retina_masks=False,
    embed=None,
    show=False,
    save_frames=False,
    save_txt=False,
    save_conf=False,
    save_crop=False,
    show_labels=True,
    show_conf=True,
    show_boxes=True,
    line_width=None,
    
    # ---------------- Export ----------------
    format="torchscript",
    keras=False,
    optimize=False,
    int8=False,
    dynamic=False,
    simplify=True,
    opset=None,
    workspace=None,
    nms=False,
    
    # ---------------- Optimizer Params ----------------
    lr0=0.0001,
    lrf=0.01,
    momentum=0.9,
    weight_decay=0.05,
    warmup_epochs=3.0,
    warmup_momentum=0.8,
    warmup_bias_lr=0.01,
    
    # ---------------- Loss Gains ----------------
    box=7.0,
    cls=0.25,
    dfl=1.5,
    pose=12.0,
    kobj=1.0,
    nbs=64,
    
    # ---------------- Augmentation (EXACT) ----------------
    hsv_h=0.4,
    hsv_s=0.4,
    hsv_v=0.4,
    degrees=20.0,
    translate=0.10,
    scale=0.4,
    shear=0.0,
    perspective=0.0,
    flipud=0.25,
    fliplr=0.5,
    bgr=0.0,
    mosaic=0.2,
    mixup=0.3,
    cutmix=0.2,
    copy_paste=0.2,
    copy_paste_mode="flip",
    auto_augment="None",
    erasing=0.3,
    
    # ---------------- Other ----------------
    name="merged_view_finding/yolo11l_640",
)
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA RTX A5000, 24122MiB)
# ...
